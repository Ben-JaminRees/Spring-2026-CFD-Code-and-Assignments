# %% [markdown]
# # ME5311-CFD: your 2nd CFD problem
# ## Xinyu Zhao
#
# ### 1D transient conduction in a semi-infinite wall
#
# Transient conduction in a semi-infinite wall is a common problem that can be encountered in engineering, for example, when heat transfer along a large thin wall with small thermal conductivity is of interest. The governing equation is a parabolic partial differential equation,
#
# $$ \rho c \frac{\partial T}{\partial t} = \frac{\partial}{\partial x}(k\frac{\partial T}{\partial x}) $$
#
# with boundary conditions,
#
# $$ T(x,0) = T_i, x > 0 $$
# $$ T(0,t) = T_s, t > 0 $$
# $$ T(x \to \infty, t) = T_i,  t > 0$$
#
# The numerical solution of this problem exercises spatial and temporal discretization. In particular, this is a good example to understand accuracy versus stability of a numerical method. A first-order explicit method is used to advance the solution in time, while a second-order central difference is used to discretize the spatial derivative term. The initial time step $dt$ is chosen to be right at the stability limit. Readers can increase dt to be larger than the default value to observe numerical instability.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

# Physical and numerical parameters
alpha = 1e-5       # thermal diffusivity [m^2/s]
L = 0.3            # wall depth [m]
N = 150             # number of cells (a finite volume method)
dx = L / N          # cell size for the numerical solution 
dt = 0.5*dx**2 / alpha # time step chosen. Note that 0.5 * dx**2 / alpha is the upper limit for obtaining stable solution
Nt = 5000 # number of total time steps
T_i = 300 # initial temperature of the whole domain 
T_s = 400 # boundary temperature at x = 0, at t > 0 

# Spatial grid (cell centers)
x = np.linspace(dx/2, L - dx/2, N)

# Initial condition
T = np.ones(N) * T_i
# Boundary condition
T[0] = T_s

# Time snapshots and storage
snapshots = [100, 500, 1000, 5000]
T_record = {} # empty array to host the numerical solution for T
T_analytical = {} # empty array to host the analytical solution at the same location as the numerical solution

# explicit time stepping
for n in range(1, Nt + 1):
    T_old = T.copy() # store a copy of the existing solution obtained from the previous time step
    for i in range(1, N - 1):
        T[i] = T_old[i] + alpha * dt / dx**2 * (T_old[i+1] - 2*T_old[i] + T_old[i-1]) # Eq. 3.63 in the book 
    T[0] =  T_old[0] + alpha * dt / dx**2 * (T_old[1] - 3*T_old[0] + 2*T_s) # taking care of the boundary condition at x = 0
    T[N-1]= T_old[N-1] + alpha * dt / dx**2 * (T_old[N-2] - 3*T_old[N-1] + 2*T_i) #taking care of the boundary condition at x = L
    
    if n in snapshots:
        T_record[n] = T.copy() # store the latest solution to the array, adding it to the last column
        t_now = n * dt
        T_analytical[n] = T_s + (T_i - T_s) * erf(x / (2 * np.sqrt(alpha * t_now))) # computing and store analytical solution at the same time step

# Plotting with time annotations
plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(10, 8))
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

for idx, n in enumerate(snapshots):
    t_now = n * dt
    label_text = f't = {t_now:.1f} s'
    
    # Plot numerical and analytical
    plt.plot(x, T_record[n], '-+', color=colors[idx], label=f'FVM {label_text}')
    plt.plot(x, T_analytical[n], '-', color=colors[idx], label=f'Analytical {label_text}')
    
    # Annotate time on the FVM curve
    i_annot = int(len(x) * 0.2)  # location to annotate
    plt.annotate(label_text,
                 xy=(x[i_annot], T_record[n][i_annot]),
                 xytext=(x[i_annot] + 0.005, T_record[n][i_annot] + 3),
                 fontsize=18,
                 arrowprops=dict(arrowstyle='->', color=colors[idx]))

plt.xlabel('Depth [m]', fontsize=18)
plt.ylabel('Temperature [K]', fontsize=18)
#plt.title('1D Transient Heat Conduction into Semi-Infinite Wall\n(FVM vs Analytical)', fontsize=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comments
#
# The above figure shows the temperature evolution at 20, 100, 200 and 1000~s, compared to the analytical solutions, using $\Delta t = 0.1$~s. Great agreement is achieved between the numerical and analytical solutions, verifying that the numerical procedure is correct. It is noteworthy that the temperature beyond 0.2~m is unaffected by the sudden increase of temperature (or appears to have no knowledge of the change) on the left boundary by 200 seconds. This is because diffusion occurs at finite rates, and at 200~seconds with a diffusivity of $10^{-5}$, the length scale for diffusion can be estimated using $2\sqrt{\alpha t}$ as indicated by the similarity variable, which gives a value of 0.04~m. This estimated distance is on the same order of magnitude with the observation from the results here. Further advancement in time makes the temperature significantly different from the initial temperature at the right boundary when using $L=0.3$. In other words, $L=0.3$~m violates the assumptions of semi-infinite domain in the analytical solution. As a result, a deviation between the numerical solution is observed from the analytical solution at $t=1000$~s.
#
#
# We use this Jupyter notebook to explore the idea of self-similarity.
# The following figure shows the same solutions after normalization, using the variables $\theta$ and $\eta$. All the results at different physical time instants collapse with one another, which is the meaning or signature of a ''self-similar solution''. The solution at $t = 1000$~s slightly deviates from the rest of the profiles, since it violates the semi-infinite domain assumption, as discussed above.

# %%
# Plotting with time annotations
# Plot the solution in the similarity coordinate eta = x / sqrt(alpha * t)

plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(10, 8))
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

for idx, n in enumerate(snapshots):
    t_now = n * dt
    label_text = f't = {t_now:.1f} s'
    
    theta = (T_record[n] - T_s)/(T_i - T_s)
    eta = x/2/np.sqrt(alpha*t_now)
    # Plot numerical and analytical
    plt.plot(eta, theta, '--', color=colors[idx], label=f'FVM {label_text}')
    
    # Annotate time on the FVM curve
    i_annot = int(len(x) * 0.2)  # location to annotate
    plt.annotate(label_text,
                 xy=(x[i_annot], T_record[n][i_annot]),
                 xytext=(x[i_annot] + 0.005, T_record[n][i_annot] + 3),
                 fontsize=18,
                 arrowprops=dict(arrowstyle='->', color=colors[idx]))

plt.xlabel('$\eta$', fontsize=18)
plt.ylabel('$\Theta$', fontsize=18)
#plt.title('1D Transient Heat Conduction into Semi-Infinite Wall\n(FVM vs Analytical)', fontsize=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 1
#
# Change the time step to be twice the current value and observe the temperature profiles. Comment on the results.

# %%
# Physical and numerical parameters
alpha = 1e-5       # thermal diffusivity [m^2/s]
L = 0.3            # wall depth [m]
N = 150             # number of cells (a finite volume method)
dx = L / N          # cell size for the numerical solution 
dt = 1.0*dx**2 / alpha # time step chosen. Note that 0.5 * dx**2 / alpha is the upper limit for obtaining stable solution
Nt = 2500 # number of total time steps
T_i = 300 # initial temperature of the whole domain 
T_s = 400 # boundary temperature at x = 0, at t > 0 
# Spatial grid (cell centers)
x = np.linspace(dx/2, L - dx/2, N)

# Initial condition
T = np.ones(N) * T_i
# Boundary condition
T[0] = T_s

# Time snapshots and storage
snapshots = [100, 500, 1000, 2500]
T_record = {} # empty array to host the numerical solution for T
T_analytical = {} # empty array to host the analytical solution at the same location as the numerical solution

# explicit time stepping
for n in range(1, Nt + 1):
    T_old = T.copy() # store a copy of the existing solution obtained from the previous time step
    for i in range(1, N - 1):
        T[i] = T_old[i] + alpha * dt / dx**2 * (T_old[i+1] - 2*T_old[i] + T_old[i-1]) # Eq. 3.63 in the book 
    T[0] =  T_old[0] + alpha * dt / dx**2 * (T_old[1] - 3*T_old[0] + 2*T_s) # taking care of the boundary condition at x = 0
    T[N-1]= T_old[N-1] + alpha * dt / dx**2 * (T_old[N-2] - 3*T_old[N-1] + 2*T_i) #taking care of the boundary condition at x = L
    
    if n in snapshots:
        T_record[n] = T.copy() # store the latest solution to the array, adding it to the last column
        t_now = n * dt
        T_analytical[n] = T_s + (T_i - T_s) * erf(x / (2 * np.sqrt(alpha * t_now))) # computing and store analytical solution at the same time step

# Plotting with time annotations
plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(10, 8))
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

for idx, n in enumerate(snapshots):
    t_now = n * dt
    label_text = f't = {t_now:.1f} s'
    
    # Plot numerical and analytical
    plt.plot(x, T_record[n], '-+', color=colors[idx], label=f'FVM {label_text}')
    plt.plot(x, T_analytical[n], '-', color=colors[idx], label=f'Analytical {label_text}')
    
    # Annotate time on the FVM curve
    i_annot = int(len(x) * 0.2)  # location to annotate
    plt.annotate(label_text,
                 xy=(x[i_annot], T_record[n][i_annot]),
                 xytext=(x[i_annot] + 0.005, T_record[n][i_annot] + 3),
                 fontsize=18,
                 arrowprops=dict(arrowstyle='->', color=colors[idx]))

plt.xlabel('Depth [m]', fontsize=18)
plt.ylabel('Temperature [K]', fontsize=18)
#plt.title('1D Transient Heat Conduction into Semi-Infinite Wall\n(FVM vs Analytical)', fontsize=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/q8/j3f68nc51hlbttpdgsgg87s80000gn/T/ipykernel_46600/3802484111.py:27: RuntimeWarning: overflow encountered in scalar multiply
#   T[i] = T_old[i] + alpha * dt / dx**2 * (T_old[i+1] - 2*T_old[i] + T_old[i-1]) # Eq. 3.63 in the book
# /var/folders/q8/j3f68nc51hlbttpdgsgg87s80000gn/T/ipykernel_46600/3802484111.py:27: RuntimeWarning: overflow encountered in scalar subtract
#   T[i] = T_old[i] + alpha * dt / dx**2 * (T_old[i+1] - 2*T_old[i] + T_old[i-1]) # Eq. 3.63 in the book
# /var/folders/q8/j3f68nc51hlbttpdgsgg87s80000gn/T/ipykernel_46600/3802484111.py:27: RuntimeWarning: overflow encountered in scalar add
#   T[i] = T_old[i] + alpha * dt / dx**2 * (T_old[i+1] - 2*T_old[i] + T_old[i-1]) # Eq. 3.63 in the book
# /var/folders/q8/j3f68nc51hlbttpdgsgg87s80000gn/T/ipykernel_46600/3802484111.py:28: RuntimeWarning: overflow encountered in scalar multiply
#   T[0] =  T_old[0] + alpha * dt / dx**2 * (T_old[1] - 3*T_old[0] + 2*T_s) # taking care of the boundary condition at x = 0
# /var/folders/q8/j3f68nc51hlbttpdgsgg87s80000gn/T/ipykernel_46600/3802484111.py:27: RuntimeWarning: invalid value encountered in scalar add
#   T[i] = T_old[i] + alpha * dt / dx**2 * (T_old[i+1] - 2*T_old[i] + T_old[i-1]) # Eq. 3.63 in the book
# /var/folders/q8/j3f68nc51hlbttpdgsgg87s80000gn/T/ipykernel_46600/3802484111.py:28: RuntimeWarning: invalid value encountered in scalar add
#   T[0] =  T_old[0] + alpha * dt / dx**2 * (T_old[1] - 3*T_old[0] + 2*T_s) # taking care of the boundary condition at x = 0
# /var/folders/q8/j3f68nc51hlbttpdgsgg87s80000gn/T/ipykernel_46600/3802484111.py:29: RuntimeWarning: overflow encountered in scalar subtract
#   T[N-1]= T_old[N-1] + alpha * dt / dx**2 * (T_old[N-2] - 3*T_old[N-1] + 2*T_i) #taking care of the boundary condition at x = L
# /var/folders/q8/j3f68nc51hlbttpdgsgg87s80000gn/T/ipykernel_46600/3802484111.py:29: RuntimeWarning: invalid value encountered in scalar add
#   T[N-1]= T_old[N-1] + alpha * dt / dx**2 * (T_old[N-2] - 3*T_old[N-1] + 2*T_i) #taking care of the boundary condition at x = L

# %%
# Plotting with time annotations
# Plot the solution in the similarity coordinate eta = x / sqrt(alpha * t)

plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(10, 8))
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

for idx, n in enumerate(snapshots):
    t_now = n * dt
    label_text = f't = {t_now:.1f} s'
    
    theta = (T_record[n] - T_s)/(T_i - T_s)
    eta = x/2/np.sqrt(alpha*t_now)
    # Plot numerical and analytical
    plt.plot(eta, theta, '--', color=colors[idx], label=f'FVM {label_text}')
    
    # Annotate time on the FVM curve
    i_annot = int(len(x) * 0.2)  # location to annotate
    plt.annotate(label_text,
                 xy=(x[i_annot], T_record[n][i_annot]),
                 xytext=(x[i_annot] + 0.005, T_record[n][i_annot] + 3),
                 fontsize=18,
                 arrowprops=dict(arrowstyle='->', color=colors[idx]))

plt.xlabel('$\eta$', fontsize=18)
plt.ylabel('$\Theta$', fontsize=18)
#plt.title('1D Transient Heat Conduction into Semi-Infinite Wall\n(FVM vs Analytical)', fontsize=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 1 Analysis
#
# Doubling the time step using this first explicit method clearly induces oscillatory-unstable behavior resulting in massive (10^238 K!) temperature oscillations. With these results, the numerical solution is not only orders of magnitude away from the analytical solution but also is nowhere near the self-similar behavior.

# %% [markdown]
# ### Exercise 2
#
# Discretize the governing equation using a first-order implicit time-stepping scheme and program an implicit solver for the same problem. Once the program is ready, solve the problem using two time steps dt = 0.5*dx^2 / alpha and dt = dx^2 / alpha. Compare to results from the explicit time-stepping scheme in terms of accuracy and stability.

# %% [markdown]
# ### Discretization derivation
#
# Instead of a feed-forward time stepping, the implicit time discretization will form a linear system to be solved, since current derivatives all depend on future values. As a result, all cells must be solved simulateneously to close the system. The implicit system takes the form:
# $$
# AT^{n+1}=b.
# $$
#
# This is derived from the following equation:
# $$
# \rho c_p \frac{\partial T}{\partial t} = \frac{\partial}{\partial x}(k\frac{\partial T}{\partial x}).
# $$
#
# Assuming constant $k$, dividing by $\rho c_p$ allows for use of the thermal diffusivity $\alpha$:
# $$
# \frac{\partial T}{\partial t} = \alpha\frac{\partial^2 T}{\partial x^2}.
# $$
#
# The discretization comes from using a forward difference approximation for derivatives in time:
# $$
# \frac{\partial T}{\partial t}\approx\frac{T^{n+1}_{i}-T^n_i}{\Delta t},
# $$
# and central difference FVM for the second spatial derivatives using the future time step:
# $$
# \frac{\partial^2 T}{\partial x^2}\approx\frac{T_{i+1}^{n+1}-2T^{n+1}_i+T^{n+1}_{i-1}}{\Delta x^2}.
# $$
#
# By introducing the local Fourier number $Fo$, substituting into the full equation can be simplified:
# $$
# Fo = \frac{\alpha\Delta t}{\Delta x^2}
# $$
# $$
# T_i^{n+1}-T_i^n=Fo(T^{n+1}_{i+1}-2T^{n+1}_i+T^{n+1}_{i-1}).
# $$
#
# Putting all unknowns on one side of the equation:
# $$
# -FoT^{n+1}_{i-1}+(1+2Fo)T^{n+1}_i-FoT^{n+1}_{i+1}=T^n_i.
# $$
#
# This system is unconditionally stable because the implicit coupling ensures infinite numerical signal speed, which matches the parablic nature of the heat equation.
#
# The left and right boundary of the matrix are written slightly differently due to the half cell distance from the boundary. The left side is derived by:
# $$
# \frac{T_0^{n+1}-T^n_0}{\Delta t}=\frac{\alpha}{\Delta x}\left(\left.\frac{\partial T}{\partial x}\right|_{east}-\left.\frac{\partial T}{\partial x}\right|_{west}\right)
# $$
# $$
# \left.\frac{\partial T}{\partial x}\right|_{east} = \frac{T^{n+1}_1-T^{n+1}_0}{\Delta x}
# $$
# $$
# \left.\frac{\partial T}{\partial x}\right|_{west} = \frac{T_0^{n+1}-T_S}{\Delta x/2}=\frac{2(T_0^{n+1}-T_S)}{\Delta x}
# $$
# $$
# T_0^{n+1}-T^n_0 = Fo (T^{n+1}_1-T^{n+1}_0-2T^{n+1}_0+2T_S)
# $$
# $$
# \rightarrow (1+3Fo)T^{n+1}_0-FoT^{n+1}_1=T^n_0+2FoT_S.
# $$
#
# Evaluating the right boundary similarly results in:
# $$
# -FoT^{n+1}_{N-2}+(1+3Fo)T^{n+1}_{N-1}=T^n_{N-1}+2FoT_i.
# $$
#
# These are implemented in the matrix A and solution vector b as shown below.

# %%
from scipy.linalg import solve

# Physical and numerical parameters
alpha = 1e-5       # thermal diffusivity [m^2/s]
L = 0.3            # wall depth [m]
N = 150             # number of cells (a finite volume method)
dx = L / N          # cell size for the numerical solution 
dt = 0.5*dx**2 / alpha # time step chosen. Note that 0.5 * dx**2 / alpha is the upper limit for obtaining stable solution
Nt = 5000 # number of total time steps
T_i = 300 # initial temperature of the whole domain 
T_s = 400 # boundary temperature at x = 0, at t > 0 

# Initial condition
T = np.ones(N) * T_i

# Spatial grid (cell centers)
x = np.linspace(dx/2, L - dx/2, N)

# Time snapshots and storage
snapshots = [100, 500, 1000, 5000]
T_record = {} # empty array to host the numerical solution for T
T_analytical = {} # empty array to host the analytical solution at the same location as the numerical solution



# 1. Define the coefficient Fo
Fo = alpha * dt / dx**2

# 2. Build the Matrix A (It is constant, so we build it once outside the loop)
# We are solving the system: A * T_new = b
A = np.zeros((N, N))

# Fill Main Diagonal
# Interior nodes have (1 + 2Fo), Boundaries have (1 + 3Fo)
np.fill_diagonal(A, 1 + 2 * Fo)
A[0, 0] = 1 + 3 * Fo
A[N-1, N-1] = 1 + 3 * Fo

# Fill Off-Diagonals with -Fo
for i in range(N - 1):
    A[i, i+1] = -Fo      # Upper diagonal
    A[i+1, i] = -Fo      # Lower diagonal

# 3. Time Stepping Loop
for n in range(1, Nt + 1):
    T_old = T.copy()
    
    # Construct the RHS vector b
    # Generally, b = T_old, but we must add the constant boundary terms
    b = T_old.copy()
    
    # Add the boundary contributions derived from your specific BC equations
    b[0]   += 2 * Fo * T_s
    b[N-1] += 2 * Fo * T_i
    
    # Solve the linear system A * T = b
    T = solve(A, b)
    
    # Store snapshots
    if n in snapshots:
        T_record[n] = T.copy()
        t_now = n * dt
        # Analytical solution (unchanged)
        T_analytical[n] = T_s + (T_i - T_s) * erf(x / (2 * np.sqrt(alpha * t_now)))

# %%
print(f"Fourier number Fo = {Fo}")
print(f"Matrix Condition: {np.linalg.cond(A)}") # Should be finite, not Inf

# Visual check of the matrix structure
plt.spy(A) 
plt.title("Matrix A Structure (Should be a diagonal line)")
plt.show()

# Check the first few rows manually
print("Row 0 (Left Boundary):", A[0, :4])
print("Row 1 (Interior):     ", A[1, :4])
# Out:
# Fourier number Fo = 0.5
# Matrix Condition: 2.999342194692112
# Row 0 (Left Boundary): [ 2.5 -0.5  0.   0. ]
# Row 1 (Interior):      [-0.5  2.  -0.5  0. ]

# %%
# Plotting with time annotations
plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(10, 8))
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

for idx, n in enumerate(snapshots):
    t_now = n * dt
    label_text = f't = {t_now:.1f} s'
    
    # Plot numerical and analytical
    plt.plot(x, T_record[n], '-+', color=colors[idx], label=f'FVM {label_text}')
    plt.plot(x, T_analytical[n], '-', color=colors[idx], label=f'Analytical {label_text}')
    
    # Annotate time on the FVM curve
    i_annot = int(len(x) * 0.2)  # location to annotate
    plt.annotate(label_text,
                 xy=(x[i_annot], T_record[n][i_annot]),
                 xytext=(x[i_annot] + 0.005, T_record[n][i_annot] + 3),
                 fontsize=18,
                 arrowprops=dict(arrowstyle='->', color=colors[idx]))

plt.xlabel('Depth [m]', fontsize=18)
plt.ylabel('Temperature [K]', fontsize=18)
#plt.title('1D Transient Heat Conduction into Semi-Infinite Wall\n(FVM vs Analytical)', fontsize=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Physical and numerical parameters
alpha = 1e-5       # thermal diffusivity [m^2/s]
L = 0.3            # wall depth [m]
N = 150             # number of cells (a finite volume method)
dx = L / N          # cell size for the numerical solution 
dt = 1.0*dx**2 / alpha # time step chosen. 0.5 * dx**2 / alpha is the upper limit for obtaining stable solution, but we can use a larger dt since we are using an implicit method
Nt = 2500 # number of total time steps
T_i = 300 # initial temperature of the whole domain 
T_s = 400 # boundary temperature at x = 0, at t > 0 

# Initial condition
T = np.ones(N) * T_i

# Spatial grid (cell centers)
x = np.linspace(dx/2, L - dx/2, N)

# Time snapshots and storage
snapshots = [100, 500, 1000, 2500]
T_record = {} # empty array to host the numerical solution for T
T_analytical = {} # empty array to host the analytical solution at the same location as the numerical solution


# 1. Define the coefficient Fo
Fo = alpha * dt / dx**2

# 2. Build the Matrix A (It is constant, so we build it once outside the loop)
# We are solving the system: A * T_new = b
A = np.zeros((N, N))

# Fill Main Diagonal
# Interior nodes have (1 + 2Fo), Boundaries have (1 + 3Fo)
np.fill_diagonal(A, 1 + 2 * Fo)
A[0, 0] = 1 + 3 * Fo
A[N-1, N-1] = 1 + 3 * Fo

# Fill Off-Diagonals with -Fo
for i in range(N - 1):
    A[i, i+1] = -Fo      # Upper diagonal
    A[i+1, i] = -Fo      # Lower diagonal

# 3. Time Stepping Loop
for n in range(1, Nt + 1):
    T_old = T.copy()
    
    # Construct the RHS vector b
    # Generally, b = T_old, but we must add the constant boundary terms
    b = T_old.copy()
    
    # Add the boundary contributions derived from your specific BC equations
    b[0]   += 2 * Fo * T_s
    b[N-1] += 2 * Fo * T_i
    
    # Solve the linear system A * T = b
    T = solve(A, b)
    
    # Store snapshots
    if n in snapshots:
        T_record[n] = T.copy()
        t_now = n * dt
        # Analytical solution (unchanged)
        T_analytical[n] = T_s + (T_i - T_s) * erf(x / (2 * np.sqrt(alpha * t_now)))

# Plotting with time annotations
plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(10, 8))
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

for idx, n in enumerate(snapshots):
    t_now = n * dt
    label_text = f't = {t_now:.1f} s'
    
    # Plot numerical and analytical
    plt.plot(x, T_record[n], '-+', color=colors[idx], label=f'FVM {label_text}')
    plt.plot(x, T_analytical[n], '-', color=colors[idx], label=f'Analytical {label_text}')
    
    # Annotate time on the FVM curve
    i_annot = int(len(x) * 0.2)  # location to annotate
    plt.annotate(label_text,
                 xy=(x[i_annot], T_record[n][i_annot]),
                 xytext=(x[i_annot] + 0.005, T_record[n][i_annot] + 3),
                 fontsize=18,
                 arrowprops=dict(arrowstyle='->', color=colors[idx]))

plt.xlabel('Depth [m]', fontsize=18)
plt.ylabel('Temperature [K]', fontsize=18)
#plt.title('1D Transient Heat Conduction into Semi-Infinite Wall\n(FVM vs Analytical)', fontsize=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ex. 2 Analysis
#
# The result of implementing the implicit scheme is similar behavior to the explicit scheme in its stable time-step regime but with this stability/accuracy maintained at a time step twice the size, which caused numerical explosion in the explicit scheme. The implicit scheme is shown to be much more robust against the selection of the time setp.
